# %% [markdown]
# Finals.
#
# Following my first assignment in RWET class, I wanted to continue with my sound checks.
# I needed to create a good soup with my main ingredient.
# what can be juxtapositioned/mixed with a sound check that feels natural?
# what my connection to the sound checks tells me about myself?
#
# I'm a sound check. a constant one.
# I love my body, but I am in a constant search for faults in my body, I invent symptoms and as a consequence, I ended up without results because such things don't really exist.
# I seek for diagnosis online, in the books or from my parents (both work in a hospital). the diagnosis is never enough to ease my thoughts.
# At times, I thought maybe a more psychological approach will help, things like; analysis, psychoanalysis, sitting in the psychologic office and talking for hours, online blog, web-MD, etc..all these failed to help me, my brain was faster, more efficient and it was only me that can shut it down.
#
# The nature of these thoughts is to come and go away without notice, they come in loops. because i am so aware of the process, they come with a lot of self-judgment.
# If I would need to explain how a loop looks like, it would be something like this:
# CHECK > REFLECTION ABOUT SELF > CHECK > SYMPTOMS > CHECK > DIAGNOSIS > CHECK > BEHAVIOR > SELF REFLECTION > CHECK
# I thought it a great start for a structure, which for me is the hardest part.
#
#
# Execution:
# What I liked this time about my approach to the text is that I knew what are the tools I want to use.
# it was clear how each part should be treated in terms of the library in python.
# 1 / The checks will be created randomly for a list of checks I had transcribed.
# 2 / reflection about self - I wanted to turn the online advises into reflection about my self.
# the advice for people who suffer from anexity is usually: "Stress makes sufferers feel more anxious", "don't make a change", "Doctor hopping isn't helpful", "You can swap knowledge and coping strategies". I wanted these sentences to become a reflection about my self, using spacy I was able to first detect the nouns, ADP, adjectives, and verbs. and later form a new sentence with the start of "I am ..." and maybe lead to combinations like: "i am a worried doctor". i love the nature of these empty lines: "stop worry", "control your thoughts". since they are so not helpful i just wanted to become them.(if it make any sense... )
# 3 / using JSON i imported 3 databases that I had: name of body parts, moods, and diagnosis.
# 4 /I wanted to create combinations between body parts to moods and later attach to each a random diagnosis. at first, I tried to mess up with the diagnosis data set but it turned out to me not coherent and took the focus of the entire poem. I wanted to leave the diagnosis as true to life events because this is what I usually get with I go to see my doctor.
#
# Obstacles:
# 1 / Finding the right combination with spacy took me a long time, I wanted it to have this distorted feeling, not so coherent or perfect language, phrases like: "I am similar with self" made sense to me. "I am unnecessary with increases" also had the right sound for a stressed out person.
# 2 / After having a couple of versions with the structure that I created I felt like the checks need to be more connected and integrated with all the ingredients, it should interfere the process of thought, it should disrupt the way I will read it. it will make it hard for me to read it because I know how a sound check sounds like.
#
# Picking my favorite version took me a long time, I had to run my code 60 times to understand better what I have created, all of them seemed to be ok and in the right spirit. mundane self-checks that end up to be nothing. after I will read one another one will come, just like in real life.
#
# This assignment for me was also focused on how it is going to sound like, I wanted it to be something that I can perform with. that I can play with my voice. I know that by focusing on the content I might leave less room for code exploration. I tried to change it in this final assignment but it seems like I really need to understand my materials or have a personal connection in order to create. I don't feel strong enough with word vectors and it is something that I will work probably over the summer, continue the search with my vital checks projects.  but I like the fact that I can understand spacy and tracery to a point where I could think about the use of them while thinking about the concept.
#
#
# link to my class presentation:  https://docs.google.com/presentation/d/1hZFBcKPkNpOqmuANyzR4etnzI6Mj2rfZ3Wf1OXUDG3I/edit#slide=id.g574d9170f8_0_0
#
# Dana

# %%
import tracery
import json
import random
import spacy

# %%
bodyparts = json.loads(open("bodyParts.json").read())
bodyparts2 = bodyparts['bodyParts']

moods = json.loads(open("moods.json").read())
moods2 = moods['moods']

from codes import codes

symptoms = json.loads(open("symptoms.json").read())
symptoms2 = symptoms['symptoms']

# %%
checks = [
    'one',
    'two',
    'aye',
    'hey',
    'run',
    'test',
    'run',
    'low',
    'try',
    'eco', 
    'one',
    'two',
    'aye',
    'hey',
    'run',
    'test',
    'run',
    'low',
    'try',
    'eco',  
    'tzz',
    'knock',
    'bounce',
    'b b'
    ]

# %%
nlp = spacy.load('en_core_web_md')
doc = nlp("Forget the self-checks. Connect with others who share similar concerns. Talking helps ease stress, depression, and anxiety. No need for it to be intense. Stress makes sufferers feel more anxious. You can swap knowledge and coping strategies. provide reassurance. Doctor hopping isn't helpful. hypochondriacs are inclined to do. Going from one doctor to the next increases the likelihood of different diagnoses and unnecessary tests. don't make a change. Find a therapist. Take a time-out. Stepping back from the problem helps clear your head. Eat well-balanced meals. Do not skip any meals. alcohol and caffeine can aggravate anxiety and trigger panic attacks. Get enough sleep. Exercise daily to help you feel good and maintain your health. Check out the fitness tips. Take deep breaths. Inhale and exhale slowly. Count to 10 slowly. Repeat, and count to 20 if necessary. Do your best. be proud of however close you get. Accept that you cannot control everything. Welcome humor. Maintain a positive attitude. Make an effort to replace negative thoughts with positive ones. Get involved. look for a pattern. Talk to someone. Tell friends and family you’re feeling overwhelmed, and let them know how they can help you. Talk to a physician or therapist for professional help. Distract yourself with an iPod or other portable media player. Be patient. Get online help. Drink more water. Leave screens behind before you hit the hay. Try to stick to a schedule. Be sure your bed is comfy. Keep your room's temperature on the cool side. Schedule your worry time. Breath deep. If everything is not perfect, your not a total failure. Overgeneralization. Focusing on the positives. rite down your worries. Go over your “worry list” during the worry period. Distinguish between solvable and unsolvable worries. If the worry is solvable, start brainstorming.f the worry is not solvable, accept the uncertainty.Talk about your worries. Hit the pause button on anxious thoughts. Get up and get moving. Meditate. Practice progressive muscle relaxation. cknowledge and observe your worries.Let your worries go. Stay focused on the present. ")

# %%
sentences_as_list = list(doc.sents)

# %%
for item in doc:
    print(item.text, item.pos_, item.tag_)
# Out:
# Forget VERB VB
# the DET DT
# self NOUN NN
# - PUNCT HYPH
# checks NOUN NNS
# . PUNCT .
# Connect VERB VB
# with ADP IN
# others NOUN NNS
# who NOUN WP
# share VERB VBP
# similar ADJ JJ
# concerns NOUN NNS
# . PUNCT .
# Talking VERB VBG
# helps VERB VBZ
# ease VERB VB
# stress NOUN NN
# , PUNCT ,
# depression NOUN NN
# , PUNCT ,
# and CCONJ CC
# anxiety NOUN NN
# . PUNCT .
# No DET DT
# need NOUN NN
# for ADP IN
# it PRON PRP
# to PART TO
# be VERB VB
# intense ADJ JJ
# . PUNCT .
# Stress NOUN NN
# makes VERB VBZ
# sufferers NOUN NNS
# feel VERB VB
# more ADV RBR
# anxious ADJ JJ
# . PUNCT .
# You PRON PRP
# can VERB MD
# swap VERB VB
# knowledge NOUN NN
# and CCONJ CC
# coping VERB VBG
# strategies NOUN NNS
# . PUNCT .
# provide VERB VB
# reassurance NOUN NN
# . PUNCT .
# Doctor NOUN NN
# hopping NOUN NN
# is VERB VBZ
# n't ADV RB
# helpful ADJ JJ
# . PUNCT .
# hypochondriacs NOUN NNS
# are VERB VBP
# inclined VERB VBN
# to PART TO
# do VERB VB
# . PUNCT .
# Going VERB VBG
# ...

# %%
nouns = [item.text for item in doc if item.pos_ == 'NOUN']
adp = [item.text for item in doc if item.pos_ == 'ADP']
verbs = [item.text for item in doc if item.pos_ == 'VERB']
adjectives = [item.text for item in doc if item.pos_ == 'ADJ']

# %%
# for i in range(10):
#     print(random.choice(verbs) + " " + random.choice(nouns) + " " + random.choice(adp) + " " + random.choice(adjectives))
    
for i in range(10):
    print(random.choice(adjectives) + " " + random.choice(adp) + " " + random.choice(nouns))
# Out:
# intense with meals
# good to Doctor
# enough with meals
# your on room
# necessary of physician
# overwhelmed of side
# good to others
# negative for help
# daily that increases
# helpful before problem

# %%
for item in doc.sents:
    print(item.text)
# Out:
# Forget the self-checks.
# Connect with others who share similar concerns.
# Talking helps ease stress, depression, and anxiety.
# No need for it to be intense.
# Stress makes sufferers feel more anxious.
# You can swap knowledge and coping strategies.
# provide reassurance.
# Doctor hopping isn't helpful.
# hypochondriacs are inclined to do.
# Going from one doctor to the next increases the likelihood of different diagnoses and unnecessary tests.
# don't make a change.
# Find a therapist.
# Take a time-out.
# Stepping back from the problem helps clear your head.
# Eat well-balanced meals.
# Do not skip any meals.
# alcohol and caffeine can aggravate anxiety and trigger panic attacks.
# Get enough sleep.
# Exercise daily to help you feel good and maintain your health.
# Check out the fitness tips.
# Take deep breaths.
# Inhale and exhale slowly.
# Count to 10 slowly.
# Repeat, and count to 20 if necessary.
# Do your best.
# be proud of however close you get.
# ...

# %%
rules = {
  "origin": "my #moods# #bodyparts# is #diagnoses#",
  "bodyparts": bodyparts2,
  "diagnoses": codes,
  "moods": moods2,
  "symptoms": symptoms2
}

rules2 = {
  "origin2": "my #moods# #bodyparts#",
  "bodyparts": bodyparts2,
  "diagnoses": codes,
  "moods": moods2,
  "symptoms": symptoms2
}

grammar = tracery.Grammar(rules)
grammar2 = tracery.Grammar(rules2)


for i in range(2):
    for i in range(4):
        print(random.choice(checks))

    for i in range(1):
        print("i am " + random.choice(adjectives) + " " + random.choice(adp) + " " + random.choice(nouns))   

    for i in range(2):
        print(random.choice(checks))
        print(random.choice(checks) + " " + random.choice(bodyparts2))
        print(random.choice(checks))
        print(grammar2.flatten("#origin2#") + " " + random.choice(checks) + " " + random.choice(checks))

    print(grammar.flatten("#origin#"))
    print("i am " + random.choice(adjectives) + " " + random.choice(adp) + " " + random.choice(nouns))   
    print("  ")
# Out:
# bounce
# two
# two
# eco
# i am necessary for schedule
# aye
# eco leg
# try
# my isolated ankle knock eco
# run
# eco forehead
# test
# my humiliated eyelash two b b
# my nasty upper arm is Malignant neoplasm of other and unspecified female genital organs
# i am your to knowledge
#
# run
# one
# bounce
# eco
# i am your for hypochondriacs
# eco
# run nose
# try
# my noticed thumb two low
# low
# run head
# aye
# my broken shoulder test bounce
# my neglected head is Malignant neoplasm of overlapping sites of other and unspecified parts of mouth
# i am your from doctor
